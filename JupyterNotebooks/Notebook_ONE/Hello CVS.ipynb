# %%
import pandas as pd
df = pd.read_csv("edit_1.csv")
print(df)
# Out:
#      Event  Place      Winner     Win        Date  Year
# 0      192      1  01-7-8-2-9   17829  23-03-2013  2013
# 1      192      2  09-0-2-6-9   90269  23-03-2013  2013
# 2      192      3  27-2-1-9-3  272193  23-03-2013  2013
# 3      192      4  27-7-8-5-3  277853  23-03-2013  2013
# 4      192      5  07-1-5-2-2   71522  23-03-2013  2013
# ..     ...    ...         ...     ...         ...   ...
# 114    208      3  04-7-5-8-0   47580  21-12-2019  2019
# 115    208      4  09-3-7-5-1   93751  21-12-2019  2019
# 116    208      5  07-0-7-8-5   70785  21-12-2019  2019
# 117    208      6  01-2-0-8-7   12087  21-12-2019  2019
# 118    208      7  20-3-9-1-7  203917  21-12-2019  2019
#
# [119 rows x 6 columns]

# %%
df.describe()
# Out:
#             Event       Place            Win         Year
# count  119.000000  119.000000     119.000000   119.000000
# mean   200.000000    4.000000  156233.596639  2015.529412
# std      4.919694    2.008457   91908.058751     2.098521
# min    192.000000    1.000000     163.000000  2013.000000
# 25%    196.000000    2.000000   80148.500000  2014.000000
# 50%    200.000000    4.000000  162021.000000  2015.000000
# 75%    204.000000    6.000000  232327.000000  2017.000000
# max    208.000000    7.000000  352116.000000  2019.000000

# %%
df.values
# Out:
# array([[192, 1, '01-7-8-2-9', 17829, '23-03-2013', 2013],
#        [192, 2, '09-0-2-6-9', 90269, '23-03-2013', 2013],
#        [192, 3, '27-2-1-9-3', 272193, '23-03-2013', 2013],
#        [192, 4, '27-7-8-5-3', 277853, '23-03-2013', 2013],
#        [192, 5, '07-1-5-2-2', 71522, '23-03-2013', 2013],
#        [192, 6, '11-3-1-3-6', 113136, '23-03-2013', 2013],
#        [192, 7, '05-3-5-1-3', 53513, '23-03-2013', 2013],
#        [193, 1, '16-2-3-6-7', 162367, '22-06-2013', 2013],
#        [193, 2, '09-3-2-9-4', 93294, '22-06-2013', 2013],
#        [193, 3, '11-0-6-1-2', 110612, '22-06-2013', 2013],
#        [193, 4, '23-4-3-7-0', 234370, '22-06-2013', 2013],
#        [193, 5, '26-0-3-8-9', 260389, '22-06-2013', 2013],
#        [193, 6, '33-2-9-4-4', 332944, '22-06-2013', 2013],
#        [193, 7, '28-4-8-0-5', 284805, '22-06-2013', 2013],
#        [194, 1, '28-3-9-3-6', 283936, '21-09-2013', 2013],
#        [194, 2, '21-5-6-5-9', 215659, '21-09-2013', 2013],
# ...
